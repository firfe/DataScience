# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sb

# This is the model we'll be using.
from sklearn import tree

# A convenience for displaying visualizations.
from IPython.display import Image

# Packages for rendering our tree.
import pydotplus
import graphviz

# %matplotlib inline

import json
#json_string = json.dump('Musical_Instruments_5.json')

path = 'Musical_Instruments_5.json' 
data = pd.read_json(path, lines=True) 
df = pd.DataFrame(data)

# %%
#error tokenizing data, error_bad_line=false gets rid of it but then gets rid of a ton of data
data = pd.read_csv('AmazonMusical.csv', error_bad_lines=False) 
data.head(10)
# Out:
# b'Skipping line 280: expected 12 fields, saw 15\nSkipping line 346: expected 12 fields, saw 13\nSkipping line 382: expected 12 fields, saw 20\nSkipping line 390: expected 12 fields, saw 13\nSkipping line 418: expected 12 fields, saw 25\nSkipping line 436: expected 12 fields, saw 27\nSkipping line 454: expected 12 fields, saw 22\nSkipping line 512: expected 12 fields, saw 13\nSkipping line 514: expected 12 fields, saw 16\nSkipping line 520: expected 12 fields, saw 17\nSkipping line 686: expected 12 fields, saw 13\nSkipping line 690: expected 12 fields, saw 14\nSkipping line 698: expected 12 fields, saw 16\nSkipping line 712: expected 12 fields, saw 25\nSkipping line 726: expected 12 fields, saw 27\nSkipping line 732: expected 12 fields, saw 18\nSkipping line 738: expected 12 fields, saw 49\nSkipping line 744: expected 12 fields, saw 28\nSkipping line 758: expected 12 fields, saw 19\nSkipping line 774: expected 12 fields, saw 23\nSkipping line 784: expected 12 fields, saw 13\nSkipping 
# ...
